# %%
ta=250
tc=150
na=int(input("number of adult"))
nc=int(input("number of children"))
total_A=na*ta
total_C=nc*tc

total=total_A+total_C
print("totalo amount:",total)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 ta=250
#       2 tc=150
# ----> 3 na=int(input("number of adult"))
#       4 nc=int(input("number of children"))
#       5 total_A=na*ta
#       6 total_C=nc*tc
#
# ValueError: invalid literal for int() with base 10: ''
